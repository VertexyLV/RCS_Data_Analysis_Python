# %%
import pandas as pd

# %%
tlist = pd.read_html('https://www.ss.com/lv/transport/cars/volkswagen/')

# %%
type(tlist)
# Out:
# list

# %%
len(tlist)
# Out:
# 10

# %%
tlist[7]

# %%
df = tlist[0]

# %%
df
# Out:
#     0   1                              2
# 0 NaN NaN  Izvçrstâ meklçðanaValodu rîki

# %%
df.columns
# Out:
# Index(['Sludinājumi \tdatums',              'Modelis',                 'Gads',
#                       'Tilp.',             'Nobrauk.',                 'Cena',
#                           nan,                    nan],
#       dtype='object', name=0)

# %%
df.columns = df[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-9edb213532b0> in <module>()
# ----> 1 df.columns = df[0]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    4387         try:
#    4388             object.__getattribute__(self, name)
# -> 4389             return object.__setattr__(self, name, value)
#    4390         except AttributeError:
#    4391             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     644
#     645     def _set_axis(self, axis, labels):
# --> 646         self._data.set_axis(axis, labels)
#     647         self._clear_item_cache()
#     648
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in set_axis(self, axis, new_labels)
# ...

# %%
df[0]
# Out:
# nan

# %%
df.iloc[0,:]
# Out:
# 0    Sludinājumi \tdatums
# 1                 Modelis
# 2                    Gads
# 3                   Tilp.
# 4                Nobrauk.
# 5                    Cena
# 6                     NaN
# 7                     NaN
# Name: 0, dtype: object

# %%
## How to change column values
df.columns = df.iloc[0,:]

# %%
df
# Out:
# 0   Sludinājumi \tdatums  Modelis  \
# 0   Sludinājumi \tdatums  Modelis
# 1                    NaN      NaN
# 2                    NaN      NaN
# 3                    NaN      NaN
# 4                    NaN      NaN
# 5                    NaN      NaN
# 6                    NaN      NaN
# 7                    NaN      NaN
# 8                    NaN      NaN
# 9                    NaN      NaN
# 10                   NaN      NaN
# 11                   NaN      NaN
# 12                   NaN      NaN
# 13                   NaN      NaN
# 14                   NaN      NaN
# 15                   NaN      NaN
# 16                   NaN      NaN
# 17                   NaN      NaN
# 18                   NaN      NaN
# 19                   NaN      NaN
# 20                   NaN      NaN
# 21                   NaN      NaN
# 22                   NaN      NaN
# 23                   NaN      NaN
# 24                   NaN      NaN
# 25                   NaN      NaN
# ...
